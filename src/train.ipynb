# %%
import tensorflow as tf
from SegAN_IO import SegAN_IO

# %%
if __name__ == '__main__':
    batchsize = 64
    # These shapes are considered after cropping
    mri_shape = [batchsize, 160, 160, 3]
    seg_shape = [batchsize, 160, 160, 1]
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    segan = SegAN_IO(mri_shape, seg_shape, config=config, run_name='SeganIO_29Apr')
    segan.train(seed=1234567890)
    print("Done")
# Out:
# Failed to load last globalstep. Initializing a new run...
# No model found, creating a new one...
# INFO:tensorflow:Summary name weights/S/enc_1/W:0 is illegal; using weights/S/enc_1/W_0 instead.
# INFO:tensorflow:Summary name weights/S/enc_2/W:0 is illegal; using weights/S/enc_2/W_0 instead.
# INFO:tensorflow:Summary name weights/S/enc_3/W:0 is illegal; using weights/S/enc_3/W_0 instead.
# INFO:tensorflow:Summary name weights/S/enc_4/W:0 is illegal; using weights/S/enc_4/W_0 instead.
# INFO:tensorflow:Summary name weights/S/dec_3/W:0 is illegal; using weights/S/dec_3/W_0 instead.
# INFO:tensorflow:Summary name weights/S/dec_2/W:0 is illegal; using weights/S/dec_2/W_0 instead.
# INFO:tensorflow:Summary name weights/S/dec_1/W:0 is illegal; using weights/S/dec_1/W_0 instead.
# INFO:tensorflow:Summary name weights/S/out_unbound/W:0 is illegal; using weights/S/out_unbound/W_0 instead.
# INFO:tensorflow:Summary name weights/C/enc_1/W:0 is illegal; using weights/C/enc_1/W_0 instead.
# INFO:tensorflow:Summary name weights/C/enc_2/W:0 is illegal; using weights/C/enc_2/W_0 instead.
# INFO:tensorflow:Summary name weights/C/enc_3/W:0 is illegal; using weights/C/enc_3/W_0 instead.
# Training...
# Reached a new best value for dice_score: 0.35171876470992924. Threshold reached: False
# Reached a new best value for balanced_accuracy: 0.7569721627295886. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 492
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-492 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.6122717789514599. Threshold reached: False
# Reached a new best value for balanced_accuracy: 0.8371757931063628. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 984
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-984 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.6772170965397268. Threshold reached: False
# Reached a new best value for balanced_accuracy: 0.8720924796852383. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 1476
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-1476 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7040376804423455. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.881218744173514. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 1968
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-1968 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.71460045952651. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.8832319991113589. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 2460
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-2460 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7312015787424179. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.8905155757453856. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 2952
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-2952 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7393756887253682. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.8921007115743038. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 3444
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-3444 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7492675926890519. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.8936850889118585. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 3936
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-3936 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7529170810113471. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.8970831973159856. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 4428
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-4428 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7597937223318314. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 4920
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-4920 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7646874643964332. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.8972510015550922. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 5412
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-5412 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7680810521000416. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.9003586873714204. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 5904
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-5904 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7757874979859. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.9019693796923662. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 6396
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-6396 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7789907582443935. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.9040064218168614. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 6888
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-6888 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Epoch Ended
# Training...
# Reached a new best value for dice_score: 0.784357396305513. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 7872
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-7872 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7862677806518444. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.904426604424247. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 8364
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-8364 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Epoch Ended
# Training...
# Reached a new best value for dice_score: 0.7896212992869226. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.9051501342875856. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 9348
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-9348 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7927433780827725. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.9052149076068596. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 9840
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-9840 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Reached a new best value for dice_score: 0.7976216716405453. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.9063217715445786. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 10332
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-10332 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Epoch Ended
# Training...
# Reached a new best value for dice_score: 0.8037676302920704. Threshold reached: True
# Reached a new best value for balanced_accuracy: 0.9115363612530624. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 11316
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-11316 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Epoch Ended
# Training...
# Epoch Ended
# Training...
# Epoch Ended
# Training...
# Epoch Ended
# Training...
# Epoch Ended
# Training...
# Epoch Ended
# Training...
# Reached a new best value for dice_score: 0.8084094080150181. Threshold reached: True
# Epoch Ended
# Checkpoint...
# Saving at global step 14760
# INFO:tensorflow:../models/SegAN/SeganIO_29Apr_model/model-best.ckpt-14760 is not in all_model_checkpoint_paths. Manually adding it.
# Training...
# Epoch Ended
# Training...
# Epoch Ended
# Training...
