# %%
# Out:
# [[[[214  93  66 193]
#    [110 165  17 166]
#    [122 193 128 136]]
#
#   [[214  93  66 193]
#    [110 165  17 166]
#    [122 193 128 136]]]
#
#
#  [[[214  93  66 193]
#    [110 165  17 166]
#    [122 193 128 136]]
#
#   [[214  93  66 193]
#    [110 165  17 166]
#    [122 193 128 136]]]]
# (2, 2, 3, 4)
# [[[[214  93  66 193]
#    [110 165  17 166]
#    [122 193 128 136]]
#
#   [[214  93  66 193]
#    [110 165  17 166]
#    [122 193 128 136]]]
#
#
#  [[[214  93  66 193]
#    [110 165  17 166]
#    [122 193 128 136]]
#
#   [[214  93  66 193]
#    [110 165  17 166]
#    [122 193 128 136]]]]
# [array([[[214, 214],
#         [214, 214]],
#
#        [[ 93,  93],
#         [ 93,  93]],
#
#        [[ 66,  66],
#         [ 66,  66]],
#
#        [[193, 193],
#         [193, 193]]]), array([[[110, 110],
#         [110, 110]],
#
#        [[165, 165],
#         [165, 165]],
#
#        [[ 17,  17],
#         [ 17,  17]],
#
#        [[166, 166],
#         [166, 166]]]), array([[[122, 122],
# ...
