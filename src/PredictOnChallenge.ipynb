# %%
from DeepMRI import DeepMRI
import tensorflow as tf
import numpy as np
import SegAN_IO_arch as seganio
import SegAN_arch as seganorig
import glob
import dataset_helpers as dh
import os

# %%
models_path = 'models/'
checkpoint_basename = 'best_dice_score_'
model_name = "Segan_IO_TF2_brats_ALL"

model_epoch = 1123
mri_types=["MR_T1", "MR_T1c", "MR_T2", "MR_Flair"]
architecture=seganio
dataset='brats'
dataset_name = 'brats2015_testing_challenge_crop_mri'
dataset_center_crop = [180, 180, 128] # Cropping done at dataset generation
network_center_crop = [160, 160, len(mri_types)] # Cropping done to each slice
out_folder = 'results/' + dataset_name + '/' + model_name + '/'
description = model_name + '_' + dataset_name
os.makedirs(out_folder, exist_ok=True)

# %%
model_checkpoint = glob.glob(models_path + model_name + '/' + checkpoint_basename + str(model_epoch) + '*.index')[0].replace('.index', '')
model = DeepMRI(batch_size=64, size=network_center_crop[0], mri_channels=len(mri_types), model_name=model_name)
#model.load_dataset(dataset=dataset, mri_types=mri_types)
model.build_model(load_model=model_checkpoint, seed=1234567890, arch=architecture)
# Out:
# Using architecture: SegAN_IO_arch
# Loaded history from models/Segan_IO_TF2_brats_ALL/log_train.csv
# Loaded history from models/Segan_IO_TF2_brats_ALL/log_valid.csv
# Loading models/Segan_IO_TF2_brats_ALL/best_dice_score_1123-51
# Loaded model from: models/Segan_IO_TF2_brats_ALL/best_dice_score_1123-51, next epoch: 1272

# %%
challenge_dataset = lambda: dh.load_dataset('../datasets/'+dataset_name,
                                                mri_type=mri_types,
                                                has_ground_truth=False,
                                                center_crop=network_center_crop,
                                                batch_size=64,
                                                prefetch_buffer=1,
                                                clip_labels_to=1.0,
                                                infinite=False, 
                                                cache=False,
                                                shuffle=False
                                            )

# %%
def pad_volume(volume, original_dimension):
    '''
    Volume and original dimensions must be of shape (Z, X, Y)
    '''
    pads = []
    
    for full, crop in zip(original_dimension, volume.shape):
        pad = (full - crop)/2
        if pad % int(pad) == 0:
            pads.append((int(pad), int(pad)))
        else:
            pads.append((int(pad - .5), int(pad + .5)))
    print("Volume shape: " + str(volume.shape))
    print(pads)
    return np.pad(volume, pads, mode='constant')

def build_output_filename(flair_path, description):
    flair_id = path.decode('utf-8').split('.')[-2]
    return out_folder + 'VSD.' + description + '.' + str(flair_id) + '.mha'

results = {}

for b, row in enumerate(challenge_dataset()):
    pred = model.generator(row['mri'], training=False).numpy()
    
    for i, path in enumerate(row['MR_Flair_path'].numpy()):
        if path not in results:
            results[path] = {'pred':list(), 'origins':list(), 'spacing':list(), 'original_dimensions':list()}
        results[path]['pred'].append(pred[i])
        results[path]['origins'].append([row[mri_types[0]+'_'+ax+'_origin_src'].numpy()[i] for ax in ['z', 'x', 'y']])
        results[path]['spacing'].append([row[mri_types[0]+'_'+ax+'_spacing_src'].numpy()[i] for ax in ['z', 'x', 'y']])
        results[path]['original_dimensions'].append([row[mri_types[0]+'_'+ax+'_dimension_src'].numpy()[i] for ax in ['z', 'x', 'y']])
        print('\rSlice: {} batch: {} done'.format(i, b), end='')
print('\nPrediction done. Repacking Volumes...')

# %%
for path, res in results.items():
    # Format is (Z, X, Y)
    volume = np.stack(res['pred'])
    orig_dims = res['original_dimensions'][0]
    # Collapse the label dimension
    if volume.shape[-1] == 1:
        # Binary label
        volume = volume.squeeze()
    else:
        # Argmax
        volume = volume.argmax(axis=-1)
    if dataset_center_crop or network_center_crop:
        # Using original dimension to pad the images
        volume = pad_volume(volume, orig_dims)
        assert np.all(np.array(volume.shape) == orig_dims)
    origin = np.array(res['origins'][0], dtype=np.float64)
    spacing = np.array(res['spacing'][0], dtype=np.float64)
    
    filename = build_output_filename(path, description)
    dh.save_itk(volume, origin, spacing, filename)
    print('Saved MHA of shape {} at {}'.format(volume.shape, filename))
# Out:
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54193.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54199.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54205.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54215.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54221.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54227.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54233.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54239.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54245.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54251.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54257.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54263.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54269.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54275.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.54281.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40461.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40453.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40469.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40457.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40465.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40493.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40473.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40485.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40509.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40481.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40505.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40497.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40501.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40477.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40489.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40513.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40517.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.43204.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40537.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40541.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40545.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40549.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40553.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40557.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40561.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40565.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40569.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40573.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40577.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40581.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40589.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40585.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40593.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40605.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40597.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40609.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40601.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40613.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40621.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40625.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40629.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40633.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40637.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40645.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40641.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40671.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40679.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40683.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40687.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40691.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40695.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40711.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40699.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40707.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40703.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40715.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40719.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40735.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40731.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40739.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40743.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40747.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40767.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40763.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40771.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40791.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40775.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40779.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40787.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40759.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40755.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40751.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40783.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40795.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40811.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41210.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40807.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40803.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40815.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41194.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41186.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41190.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41218.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41226.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41214.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41159.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41206.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41222.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41171.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41163.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41182.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.40799.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41198.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41202.mha
# Volume shape: (128, 160, 160)
# [(13, 14), (40, 40), (40, 40)]
# (155, 240, 240)
# [155, 240, 240]
# Saved MHA of shape (155, 240, 240) at results/brats2015_training_challenge_crop_mri/Segan_IO_TF2_brats_ALL/VSD.Segan_IO_TF2_brats_ALL_brats2015_training_challenge_crop_mri.41175.mha

# %%
spacing[[0,2,1]]
# Out:
# array([1., 1., 1.], dtype=float32)

# %%
im, orig, sp = dh.load_itk(path.decode('utf-8'))

# %%
sp.dtype
# Out:
# dtype('float64')
