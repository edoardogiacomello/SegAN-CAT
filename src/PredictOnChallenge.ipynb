# %%
from DeepMRI import DeepMRI
import tensorflow as tf
import numpy as np
import SegAN_IO_arch as seganio
import SegAN_arch as seganorig
import glob
import dataset_helpers as dh
import os

# %%
# Run this for original SegAN
models_path = 'models/'
checkpoint_basename = 'best_dice_score_'
model_name = "Segan_TF2_brats_ALL"

model_epoch = 1386
mri_types=["MR_T1", "MR_T1c", "MR_T2", "MR_Flair"]
architecture=seganorig
dataset_name = 'brats2015_train_full_challenge_crop_mri'

dataset='brats'
dataset_center_crop = [180, 180, 128] # Cropping done at dataset generation
network_center_crop = [160, 160, len(mri_types)] # Cropping done to each slice
out_folder = 'results/' + dataset_name + '/' + model_name + '/'
description = model_name + '_' + dataset_name
os.makedirs(out_folder, exist_ok=True)

# %%
# Run this for our SegAN
models_path = 'models/'
checkpoint_basename = 'best_dice_score_'
model_name = "Segan_IO_TF2_brats_ALL"

model_epoch = 1123
mri_types=["MR_T1", "MR_T1c", "MR_T2", "MR_Flair"]
architecture=seganio
dataset_name = 'brats2015_train_full_challenge_mri'

dataset='brats'
# dataset_center_crop = [180, 180, 128] # Cropping done at dataset generation
# network_center_crop = [160, 160, len(mri_types)] # Cropping done to each slice
dataset_center_crop = None
network_center_crop = None
out_folder = 'results/' + dataset_name + '/' + model_name + '/'
description = model_name + '_' + dataset_name
os.makedirs(out_folder, exist_ok=True)

# %%
size = network_center_crop[0] if network_center_crop is not None else 240
model_checkpoint = glob.glob(models_path + model_name + '/' + checkpoint_basename + str(model_epoch) + '*.index')[0].replace('.index', '')
model = DeepMRI(batch_size=64, size=size, mri_channels=len(mri_types), model_name=model_name)
#model.load_dataset(dataset=dataset, mri_types=mri_types)
model.build_model(load_model=model_checkpoint, seed=1234567890, arch=architecture)
# Out:
# Using architecture: SegAN_arch
# Loading models/Segan_TF2_brats_ALL/best_dice_score_1386-13
# Loaded model from: models/Segan_TF2_brats_ALL/best_dice_score_1386-13, next epoch: 1387

# %%
challenge_dataset = lambda: dh.load_dataset('../datasets/'+dataset_name,
                                                mri_type=mri_types,
                                                has_ground_truth=False,
                                                center_crop=network_center_crop,
                                                batch_size=64,
                                                prefetch_buffer=1,
                                                clip_labels_to=1.0,
                                                infinite=False, 
                                                cache=False,
                                                shuffle=False
                                            )

# %%
def pad_volume(volume, original_dimension):
    '''
    Volume and original dimensions must be of shape (Z, X, Y)
    '''
    if np.all(np.array(volume.shape) == original_dimension):
        return volume
    pads = []
    
    for full, crop in zip(original_dimension, volume.shape):
        pad = (full - crop)/2
        if pad % int(pad) == 0:
            pads.append((int(pad), int(pad)))
        else:
            pads.append((int(pad - .5), int(pad + .5)))
    #print("Volume shape: " + str(volume.shape))
    #print(pads)
    return np.pad(volume, pads, mode='constant')

def build_output_filename(flair_path, description):
    flair_id = path.decode('utf-8').split('.')[-2]
    return out_folder + 'VSD.' + description + '.' + str(flair_id) + '.mha'

results = {}

for b, row in enumerate(challenge_dataset()):
    pred = np.greater_equal(model.generator(row['mri'], training=False).numpy(), 0.5).astype(np.int32)
    
    for i, path in enumerate(row['MR_Flair_path'].numpy()):
        if path not in results:
            results[path] = {'pred':list(), 'origins':list(), 'spacing':list(), 'original_dimensions':list()}
        results[path]['pred'].append(pred[i])
        results[path]['origins'].append([row[mri_types[0]+'_'+ax+'_origin_src'].numpy()[i] for ax in ['z', 'x', 'y']])
        results[path]['spacing'].append([row[mri_types[0]+'_'+ax+'_spacing_src'].numpy()[i] for ax in ['z', 'x', 'y']])
        results[path]['original_dimensions'].append([row[mri_types[0]+'_'+ax+'_dimension_src'].numpy()[i] for ax in ['z', 'x', 'y']])
        print('\rSlice: {} batch: {} done'.format(i, b), end='')
print('\nPredictions done. Repacking Volumes...')

for path, res in results.items():
    # Format is (Z, X, Y)
    volume = np.stack(res['pred'])
    orig_dims = res['original_dimensions'][0]
    # Collapse the label dimension
    if volume.shape[-1] == 1:
        # Binary label
        volume = volume.squeeze()
    else:
        # Argmax
        volume = volume.argmax(axis=-1)
    if dataset_center_crop or network_center_crop:
        # Using original dimension to pad the images
        volume = pad_volume(volume, orig_dims)
        assert np.all(np.array(volume.shape) == orig_dims)
    origin = np.array(res['origins'][0], dtype=np.float64)
    spacing = np.array(res['spacing'][0], dtype=np.float64)
    
    filename = build_output_filename(path, description)
    dh.save_itk(volume, origin, spacing, filename)
    print('Saved MHA of shape {} at {}'.format(volume.shape, filename))
# Out:
# Slice: 63 batch: 547 done
# Predictions done. Repacking Volumes...
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54512.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54518.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54524.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54530.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54536.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54542.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54548.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54554.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54560.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54566.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54572.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54578.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54584.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54590.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54596.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54602.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54608.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54614.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54620.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54626.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35533.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40827.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35537.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35541.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35545.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35549.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35553.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35557.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35561.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35565.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35573.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35577.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35591.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35595.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35599.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35603.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40859.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40839.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40855.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40851.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40847.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40843.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35607.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40863.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35611.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35615.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40871.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35619.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35623.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35627.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35647.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35651.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35659.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35643.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35635.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35655.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35631.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35639.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35663.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35674.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40879.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35678.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35682.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35686.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35690.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40887.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35694.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35698.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35706.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35710.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35714.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40895.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40903.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35722.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35728.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35732.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35736.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35752.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35756.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35760.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40915.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40907.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40919.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40923.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35780.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35776.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35796.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35792.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35788.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40927.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35800.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35804.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35808.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35820.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35848.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40935.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35872.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35868.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35864.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35860.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35856.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35852.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35884.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35898.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35906.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35910.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35926.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35914.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35930.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40963.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40955.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41636.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40967.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40947.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35944.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35956.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40979.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40995.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40975.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40991.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40987.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40983.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41018.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41234.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41036.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41006.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35993.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35997.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36001.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36009.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36013.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41030.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36017.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36025.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36033.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36049.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36060.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36080.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36084.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36072.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36076.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36092.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36068.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36088.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36096.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36138.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36100.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36112.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36122.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36134.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36104.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36130.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36118.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36142.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41056.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41052.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41060.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36150.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36154.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41080.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36161.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36173.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36177.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36193.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36185.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36189.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36181.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36165.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36229.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36233.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36225.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36209.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36197.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36205.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36201.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36221.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36217.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36213.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36241.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36252.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36260.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41096.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36268.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36272.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36284.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36280.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36288.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36292.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36299.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36311.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36315.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36319.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36401.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36502.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41111.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41115.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41123.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41119.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36510.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36530.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36526.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36518.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36522.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41131.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41135.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41127.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36536.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36544.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36551.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36555.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36563.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36567.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36571.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36575.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36579.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36587.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36591.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36603.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36616.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36620.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54632.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54638.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54644.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54650.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54656.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54662.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54668.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54674.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54680.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.54686.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35529.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40819.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40823.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40831.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35587.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40835.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40875.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35670.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35718.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40931.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35828.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35840.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35844.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40939.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35888.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35902.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40943.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35948.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35952.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.40971.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.35981.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36005.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41026.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41040.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36045.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41044.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41064.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41088.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36246.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41092.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41100.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36276.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41104.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36307.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36506.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36540.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41139.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41143.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36559.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41147.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.41151.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36595.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36599.mha
# Saved MHA of shape (155, 240, 240) at results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/VSD.Segan_TF2_brats_ALL_brats2015_train_full_challenge_crop_mri.36607.mha

# %%
# Metrics checking
import glob
import dataset_helpers as dh
import os
import pandas as pd
import numpy as np

def binary_stats(true, pred, thr=0.5):
    true = np.greater(true, thr)
    pred = np.greater(pred, thr)
    
    tp = np.count_nonzero(np.logical_and(true, pred))
    tn = np.count_nonzero(np.logical_and(np.logical_not(true), np.logical_not(pred)))
    fp = np.count_nonzero(np.logical_and(np.logical_not(true), pred))
    fn = np.count_nonzero(np.logical_and(true, np.logical_not(pred)))
    
    return tp, tn, fp, fn


MAX_LABELS = 1
results = pd.DataFrame()
for i, pred_path in enumerate(glob.glob('results/brats2015_train_full_challenge_crop_mri/Segan_TF2_brats_ALL/*.mha')):
    index = pred_path.split('.')[-2]
    # Find the corresponding GT
    gt_patient_folder = ['/'.join(os.path.dirname(f).split('/')[:-1]) for f in glob.glob('../../datasets/BRATS2015/BRATS2015_Training/*/*/*/*.mha') if index in f][0]
    gt_path = [f for f in glob.glob(gt_patient_folder+'/*/*.mha') if 'OT' in f][0]
    gt, _, _ = dh.load_itk(gt_path)
    pred, _, _ = dh.load_itk(pred_path)
    tp, tn, fp, fn = binary_stats(gt, pred)
    results = results.append({'gt':gt_path, 'pred':pred_path, 'tp':tp, 'tn':tn, 'fp':fp, 'fn':fn}, ignore_index=True)
    print('\r'+str(i), end="")
# Out:
# 273

# %%
results['dice'] = 2*results['tp']/(2*results['tp']+results['fp']+results['fn'])
results['sensitivity'] = results['tp']/(results['tp']+results['fn'])
results['specificity'] = results['tn']/(results['tn']+results['fp'])

# %%
results.mean()*100
# Out:
# fn             2.490427e+06
# fp             8.220266e+05
# tn             8.811074e+08
# tp             8.380181e+06
# dice           8.051681e+01
# sensitivity    7.545045e+01
# specificity    9.990678e+01
# dtype: float64
